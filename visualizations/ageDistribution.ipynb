# %% [markdown]
# Make the required imports before we use the packages.

# %%
from nba_api.stats.endpoints import playergamelog, commonallplayers, commonplayerinfo
from datetime import datetime
from collections import defaultdict
import matplotlib.pyplot as plt
import time

# %% [markdown]
# Let's get a list of all active players.

# %%
season = '2023-24'
allPlayers = commonallplayers.CommonAllPlayers(season=season, is_only_current_season=0, timeout=60).get_dict()
activePlayers = []

for player in allPlayers['resultSets'][0]['rowSet']:
	if player[3] == 1:
		activePlayers.append(player)

# %% [markdown]
# Let's get the age of each of these players, as well as how many fantasy points they have scored last season.
#
# This filters through the list of active players and looks for players who have at least played one game last season.

# %%
startdate = datetime(2023, 10, 1)
ageMap = defaultdict(list)

for player in activePlayers:
	time.sleep(3.5)

	gameLog = playergamelog.PlayerGameLog(player_id=player[0], season=season, timeout=120).get_dict()
	fpoints = []

	if len(gameLog['resultSets'][0]['rowSet']) == 0:
		continue

	playerInfo = commonplayerinfo.CommonPlayerInfo(player[0], timeout=120).get_dict()
	birthdate = playerInfo['resultSets'][0]['rowSet'][0][7]
	birthdate = datetime.strptime(birthdate, "%Y-%m-%dT%H:%M:%S")
	age = startdate.year - birthdate.year - ((startdate.month, startdate.day) < (birthdate.month, birthdate.day))

	for game in gameLog['resultSets'][0]['rowSet']:
		fieldGoalsMade = 2 * game[7]
		fieldGoalsAttempted = -1 * game[8]
		threePointersMade = game[10]
		freeThrowsMade = game[13]
		freeThrowsAttempted = -1 * game[14]
		rebounds = game[18]
		assists = 2 * game[19]
		steals = 4 * game[20]
		blocks = 4 * game[21]
		turnovers = -2 * game[22]
		points = game[24]
		fpoints.append(
			fieldGoalsMade + fieldGoalsAttempted +
			freeThrowsMade + freeThrowsAttempted +
			threePointersMade +
			rebounds + assists +
			steals + blocks +
			turnovers + points
		)

	ageMap[age].append(sum(fpoints))
	print(player[2], '->', sum(fpoints), '=>', age)
# Out:
# Precious Achiuwa -> 1520 => 24
# Bam Adebayo -> 2887 => 26
# Ochai Agbaji -> 1039 => 23
# Santi Aldama -> 1531 => 22
# Nickeil Alexander-Walker -> 1554 => 25
# Grayson Allen -> 2214 => 27
# Jarrett Allen -> 2934 => 25
# Jose Alvarado -> 975 => 25
# Kyle Anderson -> 1667 => 30
# Giannis Antetokounmpo -> 4250 => 28
# Thanasis Antetokounmpo -> 95 => 31
# Cole Anthony -> 1828 => 23
# OG Anunoby -> 1476 => 26
# Deni Avdija -> 2304 => 22
# Deandre Ayton -> 1995 => 25
# Udoka Azubuike -> 92 => 24
# Ibou Badji -> 173 => 20
# Marvin Bagley III -> 1148 => 24
# Amari Bailey -> 42 => 19
# Patrick Baldwin Jr. -> 428 => 20
# LaMelo Ball -> 1000 => 22
# Mo Bamba -> 828 => 25
# Paolo Banchero -> 3036 => 20
# Desmond Bane -> 1738 => 25
# Dalano Banton -> 984 => 23
# Dominick Barlow -> 404 => 20
# Harrison Barnes -> 1667 => 31
# Scottie Barnes -> 2731 => 22
# RJ Barrett -> 1830 => 23
# Charles Bassey -> 268 => 22
# Emoni Bates -> 59 => 19
# Keita Bates-Diop -> 530 => 27
# Nicolas Batum -> 1131 => 34
# Darius Bazley -> 132 => 23
# Bradley Beal -> 1875 => 30
# Malik Beasley -> 1691 => 26
# MarJon Beauchamp -> 415 => 22
# Jules Bernard -> 133 => 23
# Davis Bertans -> 560 => 30
# Patrick Beverley -> 1262 => 35
# Saddiq Bey -> 1561 => 24
# Goga Bitadze -> 1098 => 24
# Onuralp Bitim -> 129 => 24
# Bismack Biyombo -> 586 => 31
# Anthony Black -> 738 => 19
# Leaky Black -> 231 => 24
# Buddy Boeheim -> 49 => 23
# Bogdan Bogdanović -> 2432 => 31
# Bojan Bogdanović -> 1190 => 34
# Bol Bol -> 549 => 23
# Marques Bolden -> 121 => 25
# Devin Booker -> 3172 => 26
# Brandon Boston Jr. -> 246 => 21
# Chris Boucher -> 684 => 30
# Jamaree Bouyea -> 41 => 24
# Malaki Branham -> 1107 => 20
# Christian Braun -> 1351 => 22
# Mikal Bridges -> 2687 => 27
# Miles Bridges -> 2560 => 25
# Oshae Brissett -> 482 => 25
# Malcolm Brogdon -> 1210 => 30
# Dillon Brooks -> 1519 => 27
# Bruce Brown -> 1528 => 27
# Jaylen Brown -> 2697 => 26
# Kendall Brown -> 30 => 20
# Kobe Brown -> 252 => 23
# Moses Brown -> 180 => 23
# Greg Brown III -> 35 => 22
# Charlie Brown Jr. -> 8 => 26
# Troy Brown Jr. -> 543 => 24
# Jalen Brunson -> 3555 => 27
# Thomas Bryant -> 487 => 26
# Kobe Bufkin -> 177 => 20
# Reggie Bullock Jr. -> 260 => 32
# Alec Burks -> 1032 => 32
# Jared Butler -> 623 => 23
# Jimmy Butler -> 2334 => 34
# Jamal Cain -> 193 => 24
# Kentavious Caldwell-Pope -> 1791 => 30
# Toumani Camara -> 1262 => 23
# Clint Capela -> 2254 => 29
# Jevon Carter -> 730 => 28
# Wendell Carter Jr. -> 1334 => 24
# D.J. Carton -> 21 => 23
# Alex Caruso -> 2116 => 29
# Colin Castleton -> 46 => 23
# Julian Champagnie -> 1172 => 22
# Justin Champagnie -> 232 => 22
# Max Christie -> 621 => 20
# Sidy Cissoko -> 118 => 19
# Brandon Clarke -> 158 => 27
# Jordan Clarkson -> 1481 => 31
# Nic Claxton -> 2486 => 24
# Noah Clowney -> 326 => 19
# Amir Coffey -> 957 => 26
# John Collins -> 2060 => 26
# Zach Collins -> 1612 => 25
# Mike Conley -> 2314 => 35
# Pat Connaughton -> 1150 => 30
# Bilal Coulibaly -> 1223 => 19
# Ricky Council IV -> 267 => 22
# Robert Covington -> 481 => 32
# Torrey Craig -> 792 => 32
# Jae Crowder -> 753 => 33
# Cade Cunningham -> 2453 => 22
# Seth Curry -> 443 => 33
# Stephen Curry -> 3139 => 35
# Dyson Daniels -> 1230 => 20
# Anthony Davis -> 4204 => 30
# Johnny Davis -> 348 => 21
# JD Davison -> 50 => 20
# DeMar DeRozan -> 3279 => 34
# Donte DiVincenzo -> 2475 => 26
# Moussa Diabaté -> 77 => 21
# Mamadi Diakite -> 26 => 26
# Gradey Dick -> 836 => 19
# Ousmane Dieng -> 273 => 20
# Spencer Dinwiddie -> 1767 => 30
# Luka Dončić -> 4483 => 24
# Luguentz Dort -> 1746 => 24
# Ayo Dosunmu -> 1934 => 23
# Jeff Dowtin Jr. -> 160 => 26
# Henri Drell -> 30 => 23
# Andre Drummond -> 1732 => 30
# Chris Duarte -> 503 => 26
# David Duke Jr. -> 53 => 23
# Kris Dunn -> 1292 => 29
# Kevin Durant -> 3608 => 35
# Jalen Duren -> 2002 => 19
# Tari Eason -> 575 => 22
# Anthony Edwards -> 3364 => 22
# Kessler Edwards -> 215 => 23
# Keon Ellis -> 893 => 23
# Joel Embiid -> 2419 => 29
# Drew Eubanks -> 1090 => 26
# Tosan Evbuomwan -> 224 => 22
# Danté Exum -> 959 => 28
# Bruno Fernando -> 690 => 25
# Dorian Finney-Smith -> 1392 => 30
# Adam Flagler -> 7 => 23
# Malachi Flynn -> 796 => 25
# Simone Fontecchio -> 1350 => 27
# Jordan Ford -> 19 => 25
# Trent Forrest -> 310 => 25
# Evan Fournier -> 439 => 30
# De'Aaron Fox -> 3472 => 25
# Javon Freeman-Liberty -> 302 => 23
# Alex Fudge -> 26 => 20
# Markelle Fultz -> 817 => 25
# Andrew Funk -> 4 => 24
# Daniel Gafford -> 2489 => 25
# Danilo Gallinari -> 524 => 35
# Darius Garland -> 1910 => 23
# Usman Garuba -> 19 => 21
# Luka Garza -> 145 => 24
# Keyonte George -> 1581 => 19
# Paul George -> 3021 => 33
# Taj Gibson -> 118 => 38
# Josh Giddey -> 2331 => 20
# Harry Giles III -> 99 => 25
# Shai Gilgeous-Alexander -> 4261 => 25
# Anthony Gill -> 394 => 30
# Collin Gillespie -> 192 => 24
# Jacob Gilyard -> 606 => 25
# Rudy Gobert -> 2924 => 31
# Jordan Goodwin -> 1010 => 24
# Aaron Gordon -> 2224 => 28
# Eric Gordon -> 1454 => 34
# Devonte' Graham -> 248 => 28
# Jerami Grant -> 1681 => 29
# RaiQuan Gray -> 54 => 24
# AJ Green -> 441 => 24
# Draymond Green -> 1704 => 33
# Jalen Green -> 2535 => 21
# Javonte Green -> 267 => 30
# Jeff Green -> 917 => 37
# Josh Green -> 1055 => 22
# AJ Griffin -> 56 => 20
# Quentin Grimes -> 689 => 23
# Mouhamadou Gueye -> 98 => 25
# Mouhamed Gueye -> 83 => 20
# Rui Hachimura -> 1664 => 25
# Ashton Hagans -> 245 => 24
# Tyrese Haliburton -> 3484 => 23
# Tim Hardaway Jr. -> 1719 => 31
# James Harden -> 2981 => 34
# Jaden Hardy -> 834 => 21
# Gary Harris -> 857 => 29
# Kevon Harris -> 7 => 26
# Tobias Harris -> 2409 => 31
# Josh Hart -> 2221 => 28
# Isaiah Hartenstein -> 2146 => 25
# Sam Hauser -> 1483 => 25
# Jordan Hawkins -> 824 => 21
# Jaxson Hayes -> 792 => 23
# Gordon Hayward -> 1054 => 33
# Scoot Henderson -> 1421 => 19
# Taylor Hendricks -> 742 => 19
# Tyler Herro -> 1448 => 23
# Buddy Hield -> 2100 => 30
# Haywood Highsmith -> 1059 => 26
# Nate Hinton -> 91 => 24
# Aaron Holiday -> 1037 => 27
# Jrue Holiday -> 2206 => 33
# Justin Holiday -> 627 => 34
# Richaun Holmes -> 508 => 29
# Chet Holmgren -> 3244 => 21
# Jalen Hood-Schifino -> 34 => 20
# Al Horford -> 1728 => 37
# Talen Horton-Tucker -> 1059 => 22
# Caleb Houstan -> 460 => 20
# Jett Howard -> 53 => 20
# Kevin Huerter -> 1425 => 25
# Jay Huff -> 62 => 26
# De'Andre Hunter -> 1377 => 25
# Bones Hyland -> 511 => 23
# Joe Ingles -> 937 => 35
# Brandon Ingram -> 2424 => 26
# Kyrie Irving -> 2717 => 31
# Jonathan Isaac -> 1136 => 25
# Jaden Ivey -> 1962 => 21
# GG Jackson -> 1074 => 18
# Isaiah Jackson -> 1071 => 21
# Quenton Jackson -> 13 => 25
# Reggie Jackson -> 1599 => 33
# Andre Jackson Jr. -> 384 => 21
# Jaren Jackson Jr. -> 2490 => 24
# Trayce Jackson-Davis -> 1443 => 23
# LeBron James -> 3685 => 38
# Jaime Jaquez Jr. -> 1749 => 22
# DaQuan Jeffries -> 22 => 26
# Trey Jemison -> 461 => 23
# Ty Jerome -> 9 => 26
# Isaiah Joe -> 1291 => 24
# Cameron Johnson -> 1493 => 27
# Jalen Johnson -> 2091 => 21
# James Johnson -> 38 => 36
# Keldon Johnson -> 1936 => 23
# Keon Johnson -> 48 => 21
# Keyontae Johnson -> 20 => 23
# Nikola Jokić -> 4943 => 28
# Colby Jones -> 154 => 21
# Damian Jones -> 267 => 28
# Herbert Jones -> 2080 => 24
# Mason Jones -> 19 => 25
# Tre Jones -> 2185 => 23
# Tyus Jones -> 2247 => 27
# Derrick Jones Jr. -> 1369 => 26
# DeAndre Jordan -> 389 => 35
# Nikola Jović -> 820 => 20
# Johnny Juzang -> 244 => 22
# Luke Kennard -> 863 => 27
# Walker Kessler -> 1798 => 22
# Braxton Key -> 65 => 26
# Corey Kispert -> 1758 => 24
# Maxi Kleber -> 600 => 31
# John Konchar -> 1030 => 27
# Luke Kornet -> 1100 => 28
# Vít Krejčí -> 348 => 23
# Jonathan Kuminga -> 2016 => 20
# Kyle Kuzma -> 2569 => 28
# Jake LaRavia -> 664 => 21
# Zach LaVine -> 832 => 28
# Jock Landale -> 729 => 27
# A.J. Lawson -> 242 => 23
# Caris LeVert -> 2061 => 29
# Saben Lee -> 163 => 24
# Alex Len -> 475 => 30
# Kawhi Leonard -> 3124 => 32
# Maxwell Lewis -> 6 => 21
# Kira Lewis Jr. -> 182 => 22
# E.J. Liddell -> 19 => 22
# Damian Lillard -> 3069 => 33
# Nassir Little -> 329 => 23
# Dereck Lively II -> 1439 => 19
# Chris Livingston -> 55 => 19
# Kenneth Lofton Jr. -> 208 => 21
# Kevon Looney -> 1165 => 27
# Brook Lopez -> 2524 => 35
# Kevin Love -> 1087 => 35
# Kyle Lowry -> 1372 => 37
# Seth Lundy -> 12 => 23
# Trey Lyles -> 916 => 27
# Sandro Mamukelashvili -> 474 => 24
# Terance Mann -> 1356 => 26
# Tre Mann -> 954 => 22
# Boban Marjanović -> 88 => 35
# Lauri Markkanen -> 2208 => 26
# Naji Marshall -> 1089 => 25
# Caleb Martin -> 1339 => 28
# Cody Martin -> 603 => 28
# KJ Martin -> 531 => 22
# Garrison Mathews -> 622 => 26
# Bennedict Mathurin -> 1299 => 21
# Wesley Matthews -> 290 => 36
# Tyrese Maxey -> 3135 => 22
# Skylar Mays -> 407 => 26
# Miles McBride -> 1116 => 23
# CJ McCollum -> 2538 => 32
# T.J. McConnell -> 1874 => 31
# Jaden McDaniels -> 1479 => 23
# Jalen McDaniels -> 305 => 25
# Doug McDermott -> 614 => 31
# JaVale McGee -> 421 => 35
# Bryce McGowens -> 557 => 20
# Jordan McLaughlin -> 649 => 27
# De'Anthony Melton -> 998 => 25
# Sam Merrill -> 939 => 27
# Chimezie Metu -> 774 => 26
# Vasilije Micić -> 965 => 29
# Khris Middleton -> 1744 => 32
# Brandon Miller -> 2135 => 20
# Jordan Miller -> 18 => 23
# Leonard Miller -> 82 => 19
# Patty Mills -> 267 => 35
# Shake Milton -> 421 => 27
# Justin Minaya -> 195 => 24
# Josh Minott -> 119 => 20
# Davion Mitchell -> 750 => 25
# Donovan Mitchell -> 2681 => 27
# Evan Mobley -> 1923 => 22
# Isaiah Mobley -> 47 => 24
# Malik Monk -> 2110 => 25
# Moses Moody -> 1039 => 21
# Xavier Moon -> 92 => 28
# Wendell Moore Jr. -> 58 => 22
# Ja Morant -> 408 => 24
# Markieff Morris -> 137 => 34
# Monté Morris -> 449 => 28
# Marcus Morris Sr. -> 582 => 34
# Trey Murphy III -> 1688 => 23
# Dejounte Murray -> 3339 => 27
# Jamal Murray -> 2474 => 26
# Keegan Murray -> 2347 => 23
# Kris Murray -> 900 => 23
# Mike Muscala -> 374 => 32
# Svi Mykhailiuk -> 323 => 26
# Pete Nance -> 3 => 23
# Larry Nance Jr. -> 1153 => 30
# Andrew Nembhard -> 1449 => 23
# Aaron Nesmith -> 1801 => 23
# Georges Niang -> 1366 => 30
# Daishen Nix -> 49 => 21
# Zeke Nnaji -> 509 => 22
# Jusuf Nurkić -> 2503 => 29
# Jordan Nwora -> 699 => 25
# Royce O'Neale -> 1723 => 30
# Chuma Okeke -> 247 => 25
# Josh Okogie -> 744 => 25
# Onyeka Okongwu -> 1419 => 22
# Isaac Okoro -> 1403 => 22
# Kelly Olynyk -> 2064 => 32
# Eugene Omoruyi -> 439 => 26
# Cedi Osman -> 1054 => 28
# Kelly Oubre Jr. -> 1853 => 27
# Chris Paul -> 1710 => 38
# Cameron Payne -> 1215 => 29
# Gary Payton II -> 657 => 30
# Drew Peterson -> 25 => 23
# Julian Phillips -> 180 => 19
# Jalen Pickett -> 99 => 23
# Scotty Pippen Jr. -> 619 => 22
# Mason Plumlee -> 632 => 33
# Brandin Podziemski -> 1785 => 20
# Aleksej Pokusevski -> 363 => 21
# Jordan Poole -> 2273 => 24
# Craig Porter Jr. -> 685 => 23
# Michael Porter Jr. -> 2528 => 25
# Bobby Portis -> 2259 => 28
# Kristaps Porziņģis -> 2309 => 28
# Micah Potter -> 143 => 25
# Dwight Powell -> 723 => 32
# Norman Powell -> 1659 => 30
# Jason Preston -> 62 => 24
# Taurean Prince -> 1448 => 29
# Payton Pritchard -> 1768 => 25
# Olivier-Maxence Prosper -> 248 => 21
# Jakob Pöltl -> 1598 => 27
# Trevelin Queen -> 120 => 26
# Neemias Queta -> 448 => 24
# Immanuel Quickley -> 2132 => 24
# Lester Quinones -> 300 => 22
# Julius Randle -> 1777 => 28
# Duop Reath -> 1206 => 27
# Austin Reaves -> 2656 => 25
# Cam Reddish -> 609 => 24
# Paul Reed -> 1811 => 24
# Naz Reid -> 2138 => 24
# Jared Rhoden -> 203 => 24
# Nick Richards -> 1650 => 25
# Josh Richardson -> 860 => 30
# Duncan Robinson -> 1600 => 29
# Jerome Robinson -> 46 => 26
# Mitchell Robinson -> 690 => 25
# Orlando Robinson -> 277 => 23
# Jeremiah Robinson-Earl -> 261 => 22
# David Roddy -> 782 => 22
# Ryan Rollins -> 121 => 21
# Derrick Rose -> 369 => 34
# Terry Rozier -> 2269 => 29
# Rayan Rupert -> 338 => 19
# D'Angelo Russell -> 2774 => 27
# Matt Ryan -> 243 => 26
# Domantas Sabonis -> 4113 => 27
# Luka Samanic -> 272 => 23
# Jermaine Samuels Jr. -> 55 => 24
# Adama Sanogo -> 63 => 21
# Gui Santos -> 179 => 21
# Olivier Sarr -> 96 => 24
# Marcus Sasser -> 1235 => 23
# Admiral Schofield -> 49 => 26
# Dennis Schröder -> 2336 => 30
# Dereon Seabron -> 38 => 23
# Alperen Sengun -> 2705 => 21
# Brice Sensabaugh -> 417 => 19
# Collin Sexton -> 2469 => 24
# Landry Shamet -> 584 => 26
# Day'Ron Sharpe -> 1104 => 21
# Shaedon Sharpe -> 831 => 20
# Ben Sheppard -> 554 => 22
# Pascal Siakam -> 3126 => 29
# Ben Simmons -> 416 => 27
# Anfernee Simons -> 1600 => 24
# Jericho Sims -> 378 => 24
# Jalen Slawson -> 25 => 23
# Marcus Smart -> 570 => 29
# Jalen Smith -> 1298 => 23
# Terquavion Smith -> 99 => 20
# Dennis Smith Jr. -> 1096 => 25
# Jabari Smith Jr. -> 2202 => 20
# Nick Smith Jr. -> 480 => 19
# Jeremy Sochan -> 1904 => 20
# Pat Spencer -> 16 => 27
# Jaden Springer -> 438 => 21
# Lamar Stevens -> 565 => 26
# Isaiah Stewart -> 1078 => 22
# Julian Strawther -> 406 => 21
# Max Strus -> 1933 => 27
# Jalen Suggs -> 2003 => 22
# Cole Swider -> 53 => 24
# Jae'Sean Tate -> 741 => 27
# Jayson Tatum -> 3476 => 25
# Garrett Temple -> 209 => 37
# Dalen Terry -> 551 => 21
# Daniel Theis -> 979 => 31
# Cam Thomas -> 2034 => 21
# Isaiah Thomas -> 12 => 34
# Amen Thompson -> 1602 => 20
# Ausar Thompson -> 1495 => 20
# Klay Thompson -> 2192 => 33
# Tristan Thompson -> 472 => 32
# JT Thor -> 521 => 21
# Matisse Thybulle -> 1246 => 26
# Xavier Tillman -> 916 => 24
# Jacob Toppin -> 30 => 23
# Obi Toppin -> 1805 => 25
# Karl-Anthony Towns -> 2330 => 27
# Gary Trent Jr. -> 1685 => 24
# Oscar Tshiebwe -> 56 => 23
# P.J. Tucker -> 244 => 38
# Myles Turner -> 2647 => 27
# Hunter Tyson -> 33 => 23
# Stanley Umude -> 243 => 24
# Jonas Valančiūnas -> 2325 => 31
# Fred VanVleet -> 3137 => 29
# Jarred Vanderbilt -> 468 => 24
# Devin Vassell -> 2372 => 23
# Sasha Vezenkov -> 462 => 28
# Gabe Vincent -> 94 => 27
# Tristan Vukcevic -> 171 => 20
# Nikola Vučević -> 2909 => 32
# Dean Wade -> 848 => 26
# Franz Wagner -> 2488 => 22
# Moritz Wagner -> 1565 => 26
# Ish Wainright -> 52 => 29
# Jabari Walker -> 1370 => 21
# Jarace Walker -> 334 => 20
# Lonnie Walker IV -> 960 => 24
# Cason Wallace -> 1432 => 19
# Jordan Walsh -> 61 => 19
# T.J. Warren -> 89 => 30
# P.J. Washington -> 1947 => 25
# TyTy Washington Jr. -> 31 => 21
# Yuta Watanabe -> 223 => 28
# Lindy Waters III -> 290 => 26
# Trendon Watford -> 854 => 22
# Peyton Watson -> 1345 => 21
# Victor Wembanyama -> 3642 => 19
# Blake Wesley -> 711 => 20
# Russell Westbrook -> 1740 => 34
# Coby White -> 2669 => 23
# Derrick White -> 2707 => 29
# Dariq Whitehead -> 13 => 19
# Cam Whitmore -> 921 => 19
# Aaron Wiggins -> 1182 => 24
# Andrew Wiggins -> 1626 => 28
# Alondes Williams -> 2 => 24
# Brandon Williams -> 78 => 23
# Grant Williams -> 1603 => 24
# Jalen Williams -> 2676 => 22
# Jaylin Williams -> 889 => 21
# Kenrich Williams -> 875 => 28
# Malik Williams -> 66 => 25
# Mark Williams -> 607 => 21
# Nate Williams -> 112 => 24
# Patrick Williams -> 909 => 22
# Ziaire Williams -> 765 => 22
# Robert Williams III -> 137 => 25
# Vince Williams Jr. -> 1313 => 23
# Zion Williamson -> 2834 => 23
# Jalen Wilson -> 446 => 22
# Dylan Windler -> 96 => 27
# James Wiseman -> 1001 => 22
# Isaiah Wong -> 1 => 22
# Christian Wood -> 784 => 28
# Delon Wright -> 743 => 31
# Thaddeus Young -> 450 => 35
# Trae Young -> 2540 => 25
# Omer Yurtseven -> 528 => 25
# Cody Zeller -> 266 => 30
# Ivica Zubac -> 1977 => 26
# Dario Šarić -> 1128 => 29

# %% [markdown]
# Let's plot the graph.

# %%
for key in ageMap.keys():
	for listitem in ageMap[key]:
		plt.scatter(key, listitem, s=20)
plt.grid(True)
plt.title("Total Fantasy Points vs Player Age")
plt.xlabel("Player Age")
plt.ylabel("Total Fantasy Points")
plt.xlim(left=17, right=41)
plt.ylim(bottom=0)
plt.show()
